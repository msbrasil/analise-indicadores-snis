# %%
import shapely
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# %%
muni_atendimento = pd.read_excel('dados/atendimento_agua_municipios.xlsx')

# %%
muni_atendimento.head()
# Out:
#    Unnamed: 0  code_muni            name_muni  code_state abbrev_state  \
# 0           0     410010               Abatiá          41           PR
# 1           1     410020         Adrianópolis          41           PR
# 2           2     410030        Agudos Do Sul          41           PR
# 3           3     410040  Almirante Tamandaré          41           PR
# 4           4     410045   Altamira Do Paraná          41           PR
#
#   name_state  code_region name_region  \
# 0     Paraná            4         Sul
# 1     Paraná            4         Sul
# 2     Paraná            4         Sul
# 3     Paraná            4         Sul
# 4     Paraná            4         Sul
#
#                                             geometry  Código do Município  \
# 0  MULTIPOLYGON (((-50.22464935599999 -23.2260322...                  NaN
# 1  MULTIPOLYGON (((-48.999690821 -24.637118747999...             410020.0
# 2  MULTIPOLYGON (((-49.304332118999994 -25.947693...             410030.0
# ...
